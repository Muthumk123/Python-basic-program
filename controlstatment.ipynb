# %%
name=input("Enter the name")
if(name=="muthu"):
    print("True")
else:
    print("Faslse")
# Out:
# Enter the name pavi
# Faslse

# %%
age=int(input("Enter the age"))
if(age<=18 ):
    print("child")
else:
    print("aduld")
# Out:
# Enter the age 22
# aduld

# %%
age=int(input("Enter the age"))
if(age<18 ):
    print("child")
elif(age<35):
    print("aduld")
elif(age<59):
    print("citizen")  
else:
    print("Sinior Citizen")
# Out:
# Enter the age 70
# Sinior Citizen
