# %%
print("Hope AI")
# Out:
# Hope AI

# %%
Name=input("Enter your institute name")
# Out:
# Enter your institute name Hope AI

# %%
Name=input("Enter your name:")
Age=int(input("Enter your age:"))
School_name=input("Enter your school name:")
Drgree=input("Enter your drgree:")
# Out:
# Enter your name: Muthu kumaran M
# Enter your age: 28
# Enter your school name: Aditya vidhayashram
# Enter your drgree: BCA MBA

# %%
num1=55
num2=88
sub=(num1-num2)
print("Answer of sub is: " + str(sub))
# Out:
# Answer of sub is: -33

# %%
num1=90
num2=40
mul=(num1*num2)
print("Answer of mul is: " + str(mul))
# Out:
# Answer of mul is: 3600

# %%
num1=79.22
num2=36
div_float=(num1/num2)
print("Answer of div is: " + str(div_float))
# Out:
# Answer of div is: 2.2005555555555554

# %%
num1=76
num2=31
div_floor=(num1//num2)
print("Answer of floor is: " + str(div_floor))
# Out:
# Answer of floor is: 2

# %%
num1=4
num2=4
power=(num1**num2)
print("Answer of power numberis: " + str(power))
# Out:
# Answer of power numberis: 256
