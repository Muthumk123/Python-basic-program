# %%
num1=30
num2=788
add=num1+num2

# %%
num1=30
num2=788
add=num1+num2
print("The addition of two number is:")
print("Number1",num1)
print ("Number2",num2)
print("The answer is=" ,add)
# Out:
# The addition of two number is:
# Number1 30
# Number2 788
# The answer is= 818

# %%
num1=30
num2=788
add=num1+num2
print( "The addition of two number is:")
print("Number1",num1)
print ("Number2",num2)
print("The answer is=",add)
# Out:
# The addition of two number is:
# Number1 30
# Number2 788
# The answer is= 818
