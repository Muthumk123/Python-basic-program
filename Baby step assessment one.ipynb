# %%
print("Welcome to Assignment-1")
num1=10
num2=30
add=(num1+num2)
print(add)
# Out:
# Welcome to Assignment-1
# 40

# %%
bmi=int(input("Enter the body mass index"))
age=int(input("Enter the age"))
if(bmi>18 and age<30):    
    print("Normal")
elif(bmi>25 and age<50):    
    print("overwight")
elif(bmi>40 and age<75):
    print("Obese")
else:
    print("under wight")
# Out:
# Enter the body mass index 30
# Enter the age 60
# under wight
