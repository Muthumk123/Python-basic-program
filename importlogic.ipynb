# %%
from Mulitiplefunctions import exampleprograms

# %%
exampleprograms.oddeven(5)
# Out:
# odd number
# 'The given number is odd'

# %%
exampleprograms.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
exampleprograms.Eligible("male",20)
# Out:
# Your Gender: male
# Your Age: 20
# Not Eligible
# 'Not Eligible'

# %%
exampleprograms.marks_report(98, 87, 95, 95, 93)
# Out:
# Subject1 = 98
# Subject2 = 87
# Subject3 = 95
# Subject4 = 95
# Subject5 = 93
# Total : 468
# Percentage : 93.60000000000001

# %%
 exampleprograms.Triangle(32,34)
# Out:
# Height: 32
# Breadth: 34
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+ Height2+Breadth
# Perimeter of Triangle: 10
